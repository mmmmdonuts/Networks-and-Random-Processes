# %% [markdown]
# ## Plotting

# %% [markdown]
# General techniques for plotting: [http://matplotlib.org/1.5.3/api/pyplot_api.html#matplotlib.pyplot.plot ](http://matplotlib.org/1.5.3/api/pyplot_api.html#matplotlib.pyplot.plot ) - plot documentation

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg as lg
import time
import seaborn as sns

# %%
# globally set the fontsize 
font = {'family' : 'normal',
        'size'   : 22}
import matplotlib
matplotlib.rc('font', **font)

# %%
# generate some synthetic data to play with
num = 100
t = range(num)
x = np.random.rand(num)

# %%
plt.figure(figsize = (20,8)) #make figure larger
plt.plot(t,x, '-o',lw =1, ms = 8, c='m', label = 'blue line')
# plt.yscale('log')
# plt.xscale('log')
# plt.savefig('plot.png') # save figure (can save as pdf - higher resolution)


#### aesthetics ####
plt.title('A plot! \n title should include number of replicates and parameter values')
plt.xlabel('x label')
plt.ylabel('y label')
# plt.yticks([0,1,2],['a', 'b','c']); #can change values of ticks
# plt.xticks([0,12,30,40,52, 60,100], ['hello', 'everyone', ':)', 'nice', 'to', 'see', 'you']);
# plt.ylim([0,2]) #set y-axis to size you want
# plt.xlim([0,60])
plt.legend(loc = 'upper right', fontsize = 30)
